# %% [markdown]
# ### Os function
#
#
#
#
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | os.getcwd()      | Get current working directory | os.getcwd()                 |
# | os.chdir(path)   | Change current directory      | os.chdir("D:/Python")       |
# | os.listdir()     | Show all files and folders    | os.listdir()                |
# | os.mkdir()       | Create one folder             | os.mkdir("Student")         |
# | os.makedirs()    | Create multiple folders       | os.makedirs("Data/Student") |
# | os.rmdir()       | Delete empty folder           | os.rmdir("Student")         |
# | os.removedirs()  | Delete nested empty folders   | os.removedirs("A/B/C")      |
# | os.remove()      | Delete file                   | os.remove("data.txt")       |
# | os.rename()      | Rename file/folder            | os.rename("old","new")      |
# | os.path.exists() | Check file/folder exists      | os.path.exists("Data")      |
# | os.path.isfile() | Check file exists             | os.path.isfile("a.txt")     |
# | os.path.isdir()  | Check folder exists           | os.path.isdir("Student")    |
# | os.path.join()   | Join file paths               | os.path.join("A","B")       |

# %%
import os

# %%
os.getcwd() ###  curent working directory
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os'

# %%
path = r"c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os"
os.listdir(path)
# Out:
# ['basic.ipynb', 'college', 'hello']

# %%
path =r"c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os"
os.listdir(r"c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os")
# Out:
# ['basic.ipynb', 'college', 'hello']

# %%
#os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os'

# %%
# import shutil

# shutil.rmtree("hello")
import os

# %%
import os

print(os.access(".", os.W_OK))
# Out:
# True

# %%
os.rmdir("college")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.rmdir("college")
#
# PermissionError: [WinError 5] Access is denied: 'college'

# %%
os.rmdir("hello")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 os.rmdir("hello")
#
# PermissionError: [WinError 5] Access is denied: 'hello'

# %%
os.listdir(r'c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os')
# Out:
# ['basic.ipynb', 'college']

# %%
print("he")
# Out:
# he

# %%
os.makedirs("student\\data\\reports")   #multiple folder

# %%
os.rename("student","college")   #to rename the directory(old,nem)

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'college', 'hello']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\data science\\os'

# %%
#change directory

os.chdir(r"C:\Users\HP\OneDrive\Desktop\data science")

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.py',
#  'Deep learning',
#  'flask',
#  'GAN AI',
#  'Git &github',
#  'html & CSS',
#  'LSTM &GRU',
#  'machine learning',
#  'Matplotlib',
#  'New folder',
#  'Numpy',
#  'os',
#  'Pandas',
#  'python',
#  'Seaborn',
#  'string.py']

# %%
#join path



path = r"C:\Users\HP\OneDrive\Desktop\data science"
path1 = r"C:\Users\HP\OneDrive"
path2 = r"Desktop\data science"
complete_path = os.path.join(path1,path2)
print(complete_path)
print("final path:-",os.listdir(complete_path))
# Out:
# C:\Users\HP\OneDrive\Desktop\data science
# final path:- ['basic.py', 'Deep learning', 'flask', 'GAN AI', 'Git &github', 'he', 'hi', 'html & CSS', 'LSTM &GRU', 'machine learning', 'Matplotlib', 'New folder', 'Numpy', 'os', 'Pandas', 'python', 'Seaborn', 'string.py']

# %%
# file check krne k liye

os.path.isfile(r"C:\Users\HP\OneDrive\Desktop\data science")
# Out:
# False

# %%
# directory check krne k liye

os.path.isdir(r"C:\Users\HP\OneDrive\Desktop\data science")
# Out:
# True

# %%
os.path.isfile(r"C:\Users\HP\OneDrive\Desktop\data science\os\basic.ipynb")
# Out:
# True

# %%
#path checking of file and directory



os.path.exists(r"C:\Users\HP\OneDrive\Desktop\data science\os\basic.ipynb")
# Out:
# True

# %%
# give size of file 


os.path.getsize(r"C:\Users\HP\OneDrive\Desktop\data science\os\basic.ipynb")
# Out:
# 10828

# %%
os.makedirs("teacher\\person\\hod")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\OneDrive\\Desktop\\data science'

# %%
path =
