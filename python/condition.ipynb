# %%
print("hello")
# Out:
# hello

# %%
### condition statement
**condition statement** are use

# %% [markdown]
# #### Condition statement
#
# ***A conditional statement*** is a statement that expresses “if something happens, then something else *happens*.”

# %% [markdown]
# type of condition statemnent in python
# * if statment
# * if -else statement
# * if elif-else statemnt
# * nested if statemnt

# %% [markdown]
# <span style = "color:green"> hello world</span>

# %%
num = input("enter your number")
print(num)
print(type(num))
# Out:
# hi
# <class 'str'>

# %% [markdown]
# #### python by default string leti h
#
#
#
# isliye integer k loye int ,float k liye float denge

# %%
num = int(input("enter your number"))
print(num)
print(type(num))
# Out:
# 45
# <class 'int'>

# %%
bal = 50000
num = int (input("enter number "))
if num<bal:
    print("withdraw possible")
else:
    print("not possible")
# Out:
# not possible

# %%
bal = 30000
withdraw = int(input("Enter your Amount"))
print(withdraw)

if withdraw <= bal:
    print("apke account m paise h")

else:
    print("paise nhu h account m")
# Out:
# 100000
# paise nhu h account m

# %%
### student fail or pass

max = 33
if max<=36:
    print("fail")

else:
    print("pass")
# Out:
# fail

# %%
signal = "red"
if signal == "red":
   print("stop")

elif signal == "yellow":
   print("ready")

else:
   print("go")
# Out:
# stop

# %%
# voting systum
age = int(input("enter your age"))
print(age)
if age>= 18:
    print("eligible")

else:
    print("not eligible")
# Out:
# 34
# eligible

# %%
# gradiing systum
mark = float(input("Enter ypur mark"))
print(mark)
if mark <= 100 and mark >=90:
    print("marks is A++")

elif mark <=90 and mark >=80:
    print("marks is A") 

elif mark <=79 and mark >=70:
    print("marks is B")

elif mark <=69 and mark>=60:
    print("mark is c")
elif mark <=59 and mark >=40:
    print("D")
else:
    print("fail")
# Out:
# 34.0
# fail

# %% [markdown]
# ## nested if
#
# # syntax
# if cond1:
#
#    if cond2:
#
#           ##code
#
#      else:
#
#            ##CODE
#
# #else:
#
#     ###code

# %%
## nested if

# syntax
#if cond:
   #if cond2:
          ##code
     #else:
           ##CODE
#else
    #code

attendence = 50
marks = 33
if attendence>=75:
    if marks>=36:
        print("pass")
    else:    
        print("fail in exam")
else:
    print("low attwendece")
# Out:
# low attwendece

# %%
attendence=80
mark=23
if attendence>=75:
    if mark>=33:
        print("pass")
    else:
        print("fail")
else:
    print("no")
# Out:
# fail

# %%
#payment 
bal = 60000
pin = input("Enter your pin") 
amount= float(input("Enter ypur withdrawl amount"))
print(pin)

if pin == "muskan":
    if bal >= amount:
        print("current balance ", bal)
        print("transcation valid")
        print("amount withdrawal",amount)
    else:
        print("not efficient balance")
else:
    print("password is incorrect")
# Out:
# muskan
# 60000
# transcation valid
# amount withdrawal

# %%
pin = input("enter pin ")
amount=int(input("enetr amount"))
bal = 30000

if pin =="muskan":
    if amount<=bal:
        print("transcation valid")
        print("amount withdrawal")
    else:
        print("trancastion not valid")
else:
    print("incorect pin")
# Out:
# trancastion not valid
