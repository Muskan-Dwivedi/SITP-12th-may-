# %%
#ATM System:-
 
class ATM:
    def __init__(self):
         self.bal = 600000
         self.p= input("enter your password:")
         self.a= int(input("enter your deposit money:"))
         self.b = int(input("enter your withdraw money:"))

    def deposit_money(self):
         print("enter your deposit money:",self.a)

    def withdraw_money(self):
            print("enter withdraw money:",self.b)
         
    def check_balance(self):
         if self.a>0:
              if self.b>0:
                   self.bal= self.bal + self.a - self.b
              else:
                   self.bal = self.bal -self.b
         else:
              self.bal = self.bal+self.a
         print("check balance:",self.bal)

    def check_pass(self):
         if self.p == "muskan123":
               self.deposit_money()
               self.withdraw_money()
               self.check_balance()
         else:
              print("Password is incorrect")                  
ba =ATM()
ba.check_pass()










#output:-
# Out:
# enter your deposit money: 2000
# enter withdraw money: 500
# check balance: 601500

# %%
# BMI Metric units:-

class BMICalculator:
    def __init__(self):
        self.w = float(input("enter weight in kg:"))
        self.h = float(input("enter height in cm:"))
        self.sm= "sm"
    def height(self):
          c= self.h / 100
          self.sm= c*c
          print("height is in meter:-",self.sm)
    def weight(self):
          print("wight in kg:-",self.w)
    def calculate_bmi(self):
         self.bmi = self.w / self.sm
         print("body mass index in kg/m^2:-",self.bmi)

         if self.bmi<16:
          print(" You have severe thinness",self.bmi)
         elif 16<self.bmi<17:
          print("You have moderate thinness",self.bmi)
         elif 17<self.bmi<18.5:
          print("You have mild thinness",self.bmi)
         elif 18.5<self.bmi<25 :
          print("You have normal",self.bmi)
         elif 25<self.bmi<30:
          print("You have overweight",self.bmi)
         elif 30<self.bmi<35:
          print("You have obese class 1",self.bmi)
         elif 35<self.bmi<40:
          print("You have obsese class 2",self.bmi)
         else:
          print("You have obsese class 3",self.bmi)          
b = BMICalculator()
b.weight()
b.height()
b.calculate_bmi()





#output:-
# Out:
# wight in kg:- 60.0
# height is in meter:- 2.6244000000000005
# body mass index in kg/m^2:- 22.86236854138088
# You have normal 22.86236854138088

# %%
#BMI Standard US Units:-

class BMICalculator:
  def __init__(self):
    self.w = float(input("enter weight in kg:"))
    self.h = float(input("enter height in inches:"))
    self.b = "b"
    self.c = "c"
   
  def weight(self):
      self.b= self.w*2.205
      print("your weight in pound:",self.b)
  def height(self):
        d =self.h/2.54
        self.c = d*d
        print("your height in inches square:",self.c)
  def calculate_bmi(self):
        self.bmi = self.b/self.c
        self.bmi*703
        print("body mass index in kg/m^2:",self.bmi)
        
        if self.bmi<16:
          print(" You have severe thinness",self.bmi)
        elif 16<self.bmi<17:
         print("You have moderate thinness",self.bmi)
        elif 17<self.bmi<18.5:
         print("You have mild thinness",self.bmi)
        elif 18.5<self.bmi<25 :
         print("You have normal",self.bmi)
        elif 25<self.bmi<30:
         print("You have overweight",self.bmi)
        elif 30<self.bmi<35:
         print("You have obese class 1",self.bmi)
        elif 35<self.bmi<40:
         print("You have obsese class 2",self.bmi)
        else:
         print("You have obsese class 3",self.bmi)             
b = BMICalculator()
b.weight()
b.height()
b.calculate_bmi()

#output:-
# Out:
# your weight in pound: 132.3
# your height in inches square: 4.51980903961808
# body mass index in kg/m^2: 29.271148148148146
# You have overweight 29.271148148148146
