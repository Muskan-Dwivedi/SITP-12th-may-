# %%
#Project  ATM
 
class ATM:
    def __init__(self):
         self.bal = 600000
         self.a= int(input("enter your deposit money:"))
         self.b = int(input("enter your withdraw money:"))

    def deposit_money(self):
         print("enter your deposit money:",self.a)

    def withdraw_money(self):
            print("enter withdraw money:",self.b)


    def check_balance(self):
         if self.a>0:
              if self.b>0:
                   self.bal= self.bal + self.a - self.b
              else:
                   self.bal = self.bal -self.b
         else:
              self.bal = self.bal+self.a
         print("check balance:",self.bal)


a =ATM()
a.deposit_money()
a.withdraw_money()
a.check_balance()

# %%
## matric unit

# class BMICalculator:
#     def __init__(self):
#         self.w = float(input("enter weight in kg:"))
#         self.h = float(input("enter height in cm:"))
#         self.sm= "sm"
#     def height(self):
#           c= self.h / 100
#           self.sm= c*c
#           print("height is in meter",self.sm)
#     def weight(self):
#           print("wight in kg",self.w)
#     def calculate_bmi(self):
#      bmi = self.w / self.sm
#      print("body mass index",bmi)

#      if bmi<16:
#       print("severe thinness",bmi)
#      elif bmi>16 or bmi<17:
#       print("moderate thinness",bmi)
#      elif bmi >17 or bmi<18.5:
#       print("mild thinness",bmi)
#      elif bmi>18.5 or bmi<25 :
#       print("normal",bmi)
#      elif bmi>25 or bmi<30:
#       print("overweight",bmi)
#      elif bmi >30 or bmi<35:
#       print("obese class 1",bmi)
#      elif bmi>35 or bmi<40:
#       print("obsese class 2",bmi)
#      else:
#       print("obsese class 3",bmi)          
# b = BMICalculator()
# b.weight()
# b.height()
b.calculate_bmi()
# Out:
# body mass index 178.57142857142856
# moderate thinness 178.57142857142856

# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\OneDrive\Documents\data.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
#
#    price  spec_rating                      processor  \
# 0  49900    73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900    60.000000   12th Gen Intel Core i3 1215U
# 2  26990    69.323529  11th Gen Intel Core i3 1115G4
# 3  59729    66.000000   12th Gen Intel Core i5 1240P
# 4  69990    69.323529                       Apple M1
#
#                               CPU   Ram Ram_type    ROM ROM_type  \
# 0           Hexa Core, 12 Threads   8GB     DDR4  512GB      SSD
# 1  Hexa Core (2P + 4E), 8 Threads   8GB     DDR4  512GB      SSD
# ...

# %%
df.head(7)
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
# 5             5           5    Acer               Extensa EX214-53 Laptop
# 6             6           6    Dell     Inspiron 3520 D560896WIN9B Laptop
#
#    price  spec_rating                      processor  \
# 0  49900    73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900    60.000000   12th Gen Intel Core i3 1215U
# 2  26990    69.323529  11th Gen Intel Core i3 1115G4
# 3  59729    66.000000   12th Gen Intel Core i5 1240P
# 4  69990    69.323529                       Apple M1
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 888           926        1015  Asus
# 889           927        1016  Asus
# 890           928        1017  Asus
# 891           929        1018  Asus
# 892           930        1019  Asus
#
#                                                   name   price  spec_rating  \
# 888          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop   44990    69.323529
# 889                     TUF A15 FA577RM-HQ032WS Laptop  110000    71.000000
# 890  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...  189990    89.000000
# 891  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop  129990    73.000000
# 892  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop  131990    84.000000
#
#                          processor                             CPU   Ram  \
# 888  13th Gen ‎Intel Core i3 1315U  Hexa Core (2P + 4E), 8 Threads   8GB
# 889      6th Gen AMD Ryzen 7 6800H           Octa Core, 16 Threads  16GB
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'brand', 'name', 'price', 'spec_rating',
#        'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU',
#        'display_size', 'resolution_width', 'resolution_height', 'OS',
#        'warranty'],
#       dtype='str')

# %%
df[['ROM']]
# Out:
#        ROM
# 0    512GB
# 1    512GB
# 2    512GB
# 3    512GB
# 4    256GB
# ..     ...
# 888  512GB
# 889    1TB
# 890    1TB
# 891  512GB
# 892    1TB
#
# [893 rows x 1 columns]

# %%
df[['brand','price']]
# Out:
#       brand   price
# 0        HP   49900
# 1        HP   39900
# 2      Acer   26990
# 3    Lenovo   59729
# 4     Apple   69990
# ..      ...     ...
# 888    Asus   44990
# 889    Asus  110000
# 890    Asus  189990
# 891    Asus  129990
# 892    Asus  131990
#
# [893 rows x 2 columns]

# %%
df["brand"].unique()
# Out:
# <StringArray>
# [       'HP',      'Acer',    'Lenovo',     'Apple',      'Dell',      'Asus',
#    'Samsung',   'Ultimus', 'Primebook',       'MSI',   'Infinix',     'Wings',
#      'Honor', 'Zebronics',    'Xiaomi',     'iBall',     'Chuwi',    'Realme',
#      'Avita',    'Walker',    'Huawei',     'Tecno',  'Gigabyte',      'Vaio',
#  'Microsoft',   'Fujitsu',        'LG',   'Ninkear',     'Razer',       'AXL']
# Length: 30, dtype: str

# %%
df["brand"].nunique()
# Out:
# 30

# %%
df["brand"].value_counts()
# Out:
# brand
# HP           186
# Lenovo       169
# Asus         157
# Dell         107
# Acer          84
# MSI           65
# Samsung       28
# Apple         16
# Infinix       15
# LG             9
# Xiaomi         8
# Gigabyte       8
# Fujitsu        6
# Ultimus        4
# Zebronics      4
# Wings          3
# Chuwi          3
# Realme         3
# Tecno          3
# Honor          2
# Huawei         2
# Microsoft      2
# AXL            2
# Primebook      1
# iBall          1
# Avita          1
# Walker         1
# Vaio           1
# Ninkear        1
# Razer          1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# Length: 893, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates().sum()
# Out:
# Unnamed: 0.1                                                    417152
# Unnamed: 0                                                      465595
# brand                HPHPAcerLenovoAppleAcerDellAcerAsusSamsungLeno...
# name                 Victus 15-fb0157AX Gaming Laptop15s-fq5007TU L...
# price                                                         71357317
# spec_rating                                               61955.470588
# processor            5th Gen AMD Ryzen 5 5600H12th Gen Intel Core i...
# CPU                  Hexa Core, 12 ThreadsHexa Core (2P + 4E), 8 Th...
# Ram                  8GB8GB8GB16GB8GB8GB8GB16GB8GB16GB16GB4GB16GB4G...
# Ram_type             DDR4DDR4DDR4LPDDR5DDR4DDR4DDR4DDR5DDR4LPDDR5DD...
# ROM                  512GB512GB512GB512GB256GB512GB512GB512GB512GB5...
# ROM_type             SSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDSSDHard-Di...
# GPU                  4GB AMD Radeon RX 6500MIntel UHD GraphicsIntel...
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0.1  Unnamed: 0  brand   name  price  spec_rating  processor  \
# 0           False       False  False  False  False        False      False
# 1           False       False  False  False  False        False      False
# 2           False       False  False  False  False        False      False
# 3           False       False  False  False  False        False      False
# 4           False       False  False  False  False        False      False
# ..            ...         ...    ...    ...    ...          ...        ...
# 888         False       False  False  False  False        False      False
# 889         False       False  False  False  False        False      False
# 890         False       False  False  False  False        False      False
# 891         False       False  False  False  False        False      False
# 892         False       False  False  False  False        False      False
#
#        CPU    Ram  Ram_type    ROM  ROM_type    GPU  display_size  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1         0
# Unnamed: 0           0
# brand                0
# name                 0
# price                0
# spec_rating          0
# processor            0
# CPU                  0
# Ram                  0
# Ram_type             0
# ROM                  0
# ROM_type             0
# GPU                  0
# display_size         0
# resolution_width     0
# resolution_height    0
# OS                   0
# warranty             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
df["warranty"].unique()
# Out:
# array([1, 0, 2, 3])

# %%
warranty_dict={
    1 : "one", 0 :"zero", 2:"two",3:"three"
}

# %%
df["warranty"]=df["warranty"].map(warranty_dict)
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
# df.drop("price", axis=1,inplace=True)
# df

# %%
# df.drop(["ROM","ROM_type"],axis =1,inplace=True)
# df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
obj_val = df.select_dtypes(include="O")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13820\2737773647.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val = df.select_dtypes(include="O")

# %%
obj_val
# Out:
#       brand                                               name  \
# 0        HP                   Victus 15-fb0157AX Gaming Laptop
# 1        HP                                15s-fq5007TU Laptop
# 2      Acer                               One 14 Z8-415 Laptop
# 3    Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4     Apple                    MacBook Air 2020 MGND3HN Laptop
# ..      ...                                                ...
# 888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#                          processor                             CPU   Ram  \
# 0        5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads   8GB
# ...

# %%
num_val = df.select_dtypes(exclude="O")

# %%
num_val
# Out:
#      Unnamed: 0.1  Unnamed: 0   price  spec_rating  display_size  \
# 0               0           0   49900    73.000000          15.6
# 1               1           1   39900    60.000000          15.6
# 2               2           2   26990    69.323529          14.0
# 3               3           3   59729    66.000000          14.0
# 4               4           4   69990    69.323529          13.3
# ..            ...         ...     ...          ...           ...
# 888           926        1015   44990    69.323529          15.6
# 889           927        1016  110000    71.000000          15.6
# 890           928        1017  189990    89.000000          14.0
# 891           929        1018  129990    73.000000          15.6
# 892           930        1019  131990    84.000000          15.6
#
#      resolution_width  resolution_height
# 0              1920.0             1080.0
# 1              1920.0             1080.0
# 2              1920.0             1080.0
# ...

# %%
complete_data = pd.concat([obj_val,num_val],axis=1)

# %%
complete_data
# Out:
#       brand                                               name  \
# 0        HP                   Victus 15-fb0157AX Gaming Laptop
# 1        HP                                15s-fq5007TU Laptop
# 2      Acer                               One 14 Z8-415 Laptop
# 3    Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4     Apple                    MacBook Air 2020 MGND3HN Laptop
# ..      ...                                                ...
# 888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#                          processor                             CPU   Ram  \
# 0        5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads   8GB
# ...

# %%
hp_brand = df[df["brand"]=="HP"]
hp_brand
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                                    name  \
# 0               0           0    HP        Victus 15-fb0157AX Gaming Laptop
# 1               1           1    HP                     15s-fq5007TU Laptop
# 18             19          19    HP        Victus 15-fa0666TX Gaming Laptop
# 23             24          24    HP                     15s-fq2510tu Laptop
# 25             26          26    HP                     15s-eq2132AU Laptop
# ..            ...         ...   ...                                     ...
# 865           903         992    HP        Victus 15-fb0137AX Gaming Laptop
# 867           905         994    HP  ProBook 445 G8 7K2J8PA Business Laptop
# 872           910         999    HP        Victus 15-fb0131AX Gaming Laptop
# 876           914        1003    HP                     15s-fq3071TU Laptop
# 880           918        1007    HP        Victus 15-fb0135AX Gaming Laptop
#
# ...

# %%
hp_brand["price"].unique()
# Out:
# array([ 49900,  39900,  68990,  49580,  43990,  19850,  53790,  71990,
#         59990,  36490,  70590,  37999,  58990,  51780, 109990,  39150,
#         80990,  55850, 139234,  42990,  72999, 126742,  98174,  41950,
#         54990,  62990,  69501,  49990,  72990,  69490,  51499,  23990,
#         79990,  85999,  52990,  75533,  37990,  32790,  77889,  51990,
#         91990,  42200,  41990,  64990,  38999,  60990,  55500, 124999,
#        104990,  36999,  51999,  38990,  69990,  76900,  27890,  24999,
#         33999,  47990,  31890, 125990,  99999, 107763,  80490,  48999,
#        116990,  65600,  61990,  46490,  90490,  55990,  57990,  34250,
#         33990,  42999,  38861,  15990,  34999,  82799,  34499,  33800,
#         77990,  56990,  83249,  85490,  66648,  63490,  57580,  35999,
#         41710,  45890,  29990,  37672,  67990,  83149,  54999,  51573,
#         32990,  37290,  90464, 121900,  50490, 362999, 169999, 189999,
# ...

# %%
# p_price = hp_brand[hp_brand['price']<100000]
# hp_phrice

# %%
hp_warranety= hp_brand[hp_brand['warranty']=="three"]
hp_warranety
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand              name  price  spec_rating  \
# 481           503         570    HP  EliteBook 840 G6  90464    69.323529
#
#                        processor                   CPU  Ram Ram_type    ROM  \
# 481  8th Gen Intel Core i5 8265U  Quad Core, 8 Threads  8GB     DDR4  512GB
#
#     ROM_type                          GPU  display_size  resolution_width  \
# 481      SSD  Integrated UHD Graphics 620          14.0            1920.0
#
#      resolution_height             OS warranty
# 481             1080.0  Windows 10 OS    three

# %%
df.drop_duplicates()
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'brand', 'name', 'price', 'spec_rating',
#        'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU',
#        'display_size', 'resolution_width', 'resolution_height', 'OS',
#        'warranty'],
#       dtype='str')

# %%
df_gb = hp_brand[hp_brand["ROM"]<"16gb"]
df_gb
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                            name  price  \
# 136           140         154    HP  Chromebook 15a-na0012TU Laptop  23990
# 351           370         411    HP  Chromebook 15a-na0012TU Laptop  15990
#
#      spec_rating             processor                   CPU  Ram Ram_type  \
# 136    69.323529  Intel Celeron  N4500  Dual Core, 2 Threads  4GB  LPDDR4x
# 351    69.323529  Intel Celeron  N4500  Dual Core, 2 Threads  4GB  LPDDR4x
#
#        ROM   ROM_type                            GPU  display_size  \
# 136  128GB  Hard-Disk  Intel Integrated UHD Graphics          15.6
# 351  128GB  Hard-Disk  Intel Integrated UHD Graphics          15.6
#
#      resolution_width  resolution_height         OS warranty
# 136            1366.0              768.0  Chrome OS      one
# 351            1366.0              768.0  Chrome OS      one

# %%
acer_brand = df[df["brand"]=="Acer"]
acer_brand
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 7               7           7  Acer
# 22             23          23  Acer
# 27             28          29  Acer
# ..            ...         ...   ...
# 875           913        1002  Acer
# 879           917        1006  Acer
# 881           919        1008  Acer
# 886           924        1013  Acer
# 887           925        1014  Acer
#
#                                              name   price  spec_rating  \
# 2                            One 14 Z8-415 Laptop   26990    69.323529
# 5                         Extensa EX214-53 Laptop   39990    62.000000
# 7             Nitro V ANV15-51 2023 Gaming Laptop   76990    63.000000
# 22   Aspire 7 A715-76G UN.QMYSI.002 Gaming Laptop   54990    72.000000
# 27                Extensa 15 EX215-33 2023 Laptop   28990    69.323529
# ..                                            ...     ...          ...
# ...

# %%
acer_ram= acer_brand[acer_brand["Ram"]<"128GB"]
acer_brand
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 7               7           7  Acer
# 22             23          23  Acer
# 27             28          29  Acer
# ..            ...         ...   ...
# 875           913        1002  Acer
# 879           917        1006  Acer
# 881           919        1008  Acer
# 886           924        1013  Acer
# 887           925        1014  Acer
#
#                                              name   price  spec_rating  \
# 2                            One 14 Z8-415 Laptop   26990    69.323529
# 5                         Extensa EX214-53 Laptop   39990    62.000000
# 7             Nitro V ANV15-51 2023 Gaming Laptop   76990    63.000000
# 22   Aspire 7 A715-76G UN.QMYSI.002 Gaming Laptop   54990    72.000000
# 27                Extensa 15 EX215-33 2023 Laptop   28990    69.323529
# ..                                            ...     ...          ...
# ...

# %%
acer_rom = acer_brand[acer_brand["ROM_type"]=="SSD"]
acer_rom
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 7               7           7  Acer
# 22             23          23  Acer
# 27             28          29  Acer
# ..            ...         ...   ...
# 875           913        1002  Acer
# 879           917        1006  Acer
# 881           919        1008  Acer
# 886           924        1013  Acer
# 887           925        1014  Acer
#
#                                              name   price  spec_rating  \
# 2                            One 14 Z8-415 Laptop   26990    69.323529
# 5                         Extensa EX214-53 Laptop   39990    62.000000
# 7             Nitro V ANV15-51 2023 Gaming Laptop   76990    63.000000
# 22   Aspire 7 A715-76G UN.QMYSI.002 Gaming Laptop   54990    72.000000
# 27                Extensa 15 EX215-33 2023 Laptop   28990    69.323529
# ..                                            ...     ...          ...
# ...

# %%
df[(df["brand"]=="Apple")  & (df["price"]<200000)  &  (df["processor"]=="Apple M2") ]
# Out:
#      Unnamed: 0.1  Unnamed: 0  brand                        name   price  \
# 21             22          22  Apple     MacBook Air 2022 Laptop  104990
# 95             97         100  Apple  MacBook Air 15 2023 Laptop  126990
# 158           164         185  Apple  MacBook Air 15 2023 Laptop  144990
#
#      spec_rating processor                  CPU  Ram Ram_type    ROM ROM_type  \
# 21     69.323529  Apple M2  Octa Core (4P + 4E)  8GB     DDR4  256GB      SSD
# 95     69.323529  Apple M2  Octa Core (4P + 4E)  8GB     DDR4  256GB      SSD
# 158    69.323529  Apple M2  Octa Core (4P + 4E)  8GB     DDR4  512GB      SSD
#
#              GPU  display_size  resolution_width  resolution_height      OS  \
# 21    8-Core GPU          13.6            2560.0             1664.0  Mac OS
# 95   10-Core GPU          15.3            2880.0             1864.0  Mac OS
# 158  10-Core GPU          15.3            2880.0             1864.0  Mac OS
#
#     warranty
# 21       one
# 95       one
# ...

# %%
df.query("brand=='Asus' and price<100000 and Ram =='8GB' ")
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 8               8           8  Asus
# 15             16          16  Asus
# 20             21          21  Asus
# 89             91          94  Asus
# 102           104         107  Asus
# 106           109         112  Asus
# 132           136         150  Asus
# 154           160         180  Asus
# 156           162         182  Asus
# 174           180         203  Asus
# 205           211         239  Asus
# 257           273         306  Asus
# 267           283         318  Asus
# 279           295         331  Asus
# 281           298         334  Asus
# 286           303         339  Asus
# 307           326         365  Asus
# 325           344         384  Asus
# 352           371         412  Asus
# 359           378         419  Asus
# 384           404         449  Asus
# 394           414         466  Asus
# 399           419         471  Asus
# 410           430         489  Asus
# 415           435         498  Asus
# ...

# %%
x = df.drop("price",axis = 1)
x
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop    73.000000
# 1                                  15s-fq5007TU Laptop    60.000000
# 2                                 One 14 Z8-415 Laptop    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop    69.323529
# ..                                                 ...          ...
# ...

# %%
y = df[["price"]]
y
# Out:
#       price
# 0     49900
# 1     39900
# 2     26990
# 3     59729
# 4     69990
# ..      ...
# 888   44990
# 889  110000
# 890  189990
# 891  129990
# 892  131990
#
# [893 rows x 1 columns]

# %%
# y = mx+c

# #this is liner regression equation
# where
# m =slope
# c = intersect
# y = df[["price"]]
# x = df.drop("price",axis = 1)
    
# here y is dependent on x when x value increase then 
# y also increase

# %% [markdown]
#  y = mx+c
#
# #### #this is liner regression equation
# ##### where
# ##### m =slope
# ##### c = intersect
# #### y = df[["price"]]
# ##### x = df.drop("price",axis = 1)
#
# #### here y is dependent on x when x value increase then
# ##### y also increase
